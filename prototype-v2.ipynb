# %% [markdown]
# # Kaggle: COVID-19 Forecast
# https://www.kaggle.com/c/covid19-global-forecasting-week-3/data

# %% [markdown]
# ## Import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from ipywidgets import interact
import ipywidgets as widgets

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Import data

# %% [markdown]
# ### From Kaggle: confirmed cases and fatalities

# %%
filename = 'data/train.csv'
df_train_raw = pd.read_csv(filename)

# %%
df_train_raw.head(5)
# Out:
#    Id Province_State Country_Region        Date  ConfirmedCases  Fatalities
# 0   1            NaN    Afghanistan  2020-01-22             0.0         0.0
# 1   2            NaN    Afghanistan  2020-01-23             0.0         0.0
# 2   3            NaN    Afghanistan  2020-01-24             0.0         0.0
# 3   4            NaN    Afghanistan  2020-01-25             0.0         0.0
# 4   5            NaN    Afghanistan  2020-01-26             0.0         0.0

# %% [markdown]
# ### Demographics

# %%
filename = 'data/demographics.csv'
df_demo_raw = pd.read_csv(filename)

# %%
df_demo_raw.head(5)
# Out:
#        country country_code  \
# 0  Afghanistan          AFG
# 1  Afghanistan          AFG
# 2  Afghanistan          AFG
# 3  Afghanistan          AFG
# 4  Afghanistan          AFG
#
#                                               series        value
# 0  Age dependency ratio (% of working-age populat...   86.0007531
# 1                          Age dependency ratio, old  4.750925407
# 2                        Age dependency ratio, young  81.24982769
# 3       Age population, age 00, female, interpolated       549973
# 4         Age population, age 00, male, interpolated       581860

# %% [markdown]
# ### Human Development Index

# %%
filename = 'data/hdi.csv'
df_hdi_raw = pd.read_csv(filename)

# %%
df_hdi_raw.head(5)
# Out:
#                   country          hdi skilled_employ_ratio  \
# 0                  Norway  0.953688337          14.44329897
# 1             Switzerland  0.945936117           12.9742268
# 2                 Ireland  0.942472821          5.185185185
# 3                 Germany  0.938784706          5.791743119
# 4  Hong Kong, China (SAR)   0.93880915          1.926988266
#
#   physicians_per_10k hospital_beds_per_10k vulnerable_employment_perc_emp
# 0             46.336                    39                            4.8
# 1             42.363                    47                              9
# 2             30.861                    28                           10.9
# 3             42.087                    83                            5.9
# 4                 ..                    ..                            5.9

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# ### Select countries

# %%
# select_countries = ['Australia', 'Brazil', 'France', 'Germany', 'Italy', 'Japan', 'Korea, South',
#                     'Mexico', 'India', 'Spain', 'South Africa', 'United Kingdom', 'Turkey']

select_countries = ['Brazil', 'France', 'Germany', 'Italy', 'Japan', 'Korea, South',
                    'Spain', 'United Kingdom']

select_demo_series = ['Death rate, crude (per 1,000 people)', 'Population, total', 
                      'Population ages 0-14, total', 'Population ages 15-64, total', 'Population ages 65 and above, total']

# %%
flag = df_train_raw['Country_Region'].apply(lambda x: x in select_countries)
df_train = df_train_raw[flag].copy()

# %%
flag_country = df_demo_raw['country'].apply(lambda x: x in select_countries)
flag_series = df_demo_raw['series'].apply(lambda x: x in select_demo_series)
df_demo = df_demo_raw[(flag_country) & (flag_series)].copy()
df_demo.drop('country_code', axis=1, inplace=True)

# %%
flag = df_hdi_raw['country'].apply(lambda x: x in select_countries)
df_hdi = df_hdi_raw[flag].copy()

# %%
cols = list(df_hdi.drop('country', axis=1).columns)
df_hdi[cols] = df_hdi[cols].astype('float64')

# %% [markdown]
# ### Pivot `df_demo` series

# %%
df_demo.head()
# Out:
#      country                                series      value
# 4781  Brazil  Death rate, crude (per 1,000 people)      6.378
# 4809  Brazil           Population ages 0-14, total   45066349
# 4827  Brazil          Population ages 15-64, total  144882359
# 4869  Brazil   Population ages 65 and above, total   17885124
# 4891  Brazil                     Population, total  207833831

# %%
df_demo = pd.pivot_table(data=df_demo, index='country', columns='series', values='value', aggfunc='sum')
delete_cols = df_demo.columns

# %%
df_demo.head()
# Out:
# series  Death rate, crude (per 1,000 people) Population ages 0-14, total  \
# country
# Brazil                                 6.378                    45066349
# France                                     9                    12109162
# Germany                                 11.3                    11117936
# Italy                                   10.7                     8157364
# Japan                                   10.8                    16246827
#
# series  Population ages 15-64, total Population ages 65 and above, total  \
# country
# Brazil                     144882359                            17885124
# France                      41604279                            13151703
# Germany                     53874035                            17665031
# Italy                       38758774                            13620571
# Japan                       76168000                            34370970
#
# series  Population, total
# country
# Brazil          207833831
# France           66865144
# Germany          82657002
# Italy            60536709
# Japan           126785797

# %%
df_demo['population'] = df_demo['Population, total'].apply(int)
df_demo['death_rate_1000'] = df_demo['Death rate, crude (per 1,000 people)'].apply(float)
df_demo['population_0_14'] = df_demo['Population ages 0-14, total'].apply(int)/df_demo['population']
df_demo['population_15_64'] = df_demo['Population ages 15-64, total'].apply(int)/df_demo['population']
df_demo['population_65_above'] = df_demo['Population ages 65 and above, total'].apply(int)/df_demo['population']
df_demo.drop(delete_cols, axis=1, inplace=True)

# %%
df_demo.head(10)
# Out:
# series          population  death_rate_1000  population_0_14  \
# country
# Brazil           207833831            6.378         0.216838
# France            66865144            9.000         0.181098
# Germany           82657002           11.300         0.134507
# Italy             60536709           10.700         0.134751
# Japan            126785797           10.800         0.128144
# Korea, South      51466201            5.600         0.132255
# Spain             46593236            9.000         0.147033
# United Kingdom    66058859            9.200         0.176350
#
# series          population_15_64  population_65_above
# country
# Brazil                  0.697107             0.086055
# France                  0.622212             0.196690
# Germany                 0.651778             0.213715
# Italy                   0.640252             0.224997
# Japan                   0.600761             0.271095
# Korea, South            0.729223             0.138522
# Spain                   0.661508             0.191458
# United Kingdom          0.640739             0.182911

# %% [markdown]
# ### Aggregate cases and deaths by country

# %%
df = df_train.drop('Id', axis=1).groupby(by=['Country_Region', 'Date'], as_index=False).sum()
df.head()
# Out:
#   Country_Region        Date  ConfirmedCases  Fatalities
# 0         Brazil  2020-01-22             0.0         0.0
# 1         Brazil  2020-01-23             0.0         0.0
# 2         Brazil  2020-01-24             0.0         0.0
# 3         Brazil  2020-01-25             0.0         0.0
# 4         Brazil  2020-01-26             0.0         0.0

# %% [markdown]
# ### Check date of first case

# %%
threshold = 100
flag = df['ConfirmedCases'] >= threshold
first_case = df[flag].groupby(by=['Country_Region']).min()[['Date']]
first_case.rename(columns={'Date':'first_case'}, inplace=True)

# %% [markdown]
# ### Include first date in `df` and calculate `days`  (elapsed days)

# %%
df2 = pd.merge(df, first_case, how='left', left_on='Country_Region', right_on='Country_Region')

# %%
df2['Date'] = pd.to_datetime(df2['Date'])
df2['first_case'] = pd.to_datetime(df2['first_case'])
df2['days'] = df2['Date'] - df2['first_case']
df2['days'] = df2['days'].apply(lambda x: x.days)

# %%
flag = df2['days'] >= 0
df = df2[flag].copy()
df.head()
# Out:
#    Country_Region       Date  ConfirmedCases  Fatalities first_case  days
# 51         Brazil 2020-03-13           151.0         0.0 2020-03-13     0
# 52         Brazil 2020-03-14           151.0         0.0 2020-03-13     1
# 53         Brazil 2020-03-15           162.0         0.0 2020-03-13     2
# 54         Brazil 2020-03-16           200.0         0.0 2020-03-13     3
# 55         Brazil 2020-03-17           321.0         1.0 2020-03-13     4

# %% [markdown]
# ### Calculate `diff_cases` and `diff_deaths`

# %%
df['diff_cases'] = df['ConfirmedCases'].diff(periods=1)
df['diff_deaths'] = df['Fatalities'].diff(periods=1)
mask = df['Country_Region'] != df['Country_Region'].shift(1)
df['diff_cases'][mask] = np.nan
df['diff_deaths'][mask] = np.nan

# %%
df.head()
# Out:
#    Country_Region       Date  ConfirmedCases  Fatalities first_case  days  \
# 51         Brazil 2020-03-13           151.0         0.0 2020-03-13     0
# 52         Brazil 2020-03-14           151.0         0.0 2020-03-13     1
# 53         Brazil 2020-03-15           162.0         0.0 2020-03-13     2
# 54         Brazil 2020-03-16           200.0         0.0 2020-03-13     3
# 55         Brazil 2020-03-17           321.0         1.0 2020-03-13     4
#
#     diff_cases  diff_deaths
# 51         NaN          NaN
# 52         0.0          0.0
# 53        11.0          0.0
# 54        38.0          0.0
# 55       121.0          1.0

# %% [markdown]
# ### Join dataframes: `df`, `df_hdi`, `df_demo`

# %%
df2 = pd.merge(df, df_hdi, how='left', left_on='Country_Region', right_on='country')
df3 = pd.merge(df2, df_demo, how='left', left_on='Country_Region', right_on='country')
df3.head()
# Out:
#   Country_Region       Date  ConfirmedCases  Fatalities first_case  days  \
# 0         Brazil 2020-03-13           151.0         0.0 2020-03-13     0
# 1         Brazil 2020-03-14           151.0         0.0 2020-03-13     1
# 2         Brazil 2020-03-15           162.0         0.0 2020-03-13     2
# 3         Brazil 2020-03-16           200.0         0.0 2020-03-13     3
# 4         Brazil 2020-03-17           321.0         1.0 2020-03-13     4
#
#    diff_cases  diff_deaths country       hdi  skilled_employ_ratio  \
# 0         NaN          NaN  Brazil  0.761153              1.349538
# 1         0.0          0.0  Brazil  0.761153              1.349538
# 2        11.0          0.0  Brazil  0.761153              1.349538
# 3        38.0          0.0  Brazil  0.761153              1.349538
# 4       121.0          1.0  Brazil  0.761153              1.349538
#
#    physicians_per_10k  hospital_beds_per_10k  vulnerable_employment_perc_emp  \
# 0              21.499                   22.0                            27.6
# 1              21.499                   22.0                            27.6
# 2              21.499                   22.0                            27.6
# 3              21.499                   22.0                            27.6
# 4              21.499                   22.0                            27.6
#
#    population  death_rate_1000  population_0_14  population_15_64  \
# 0   207833831            6.378         0.216838          0.697107
# 1   207833831            6.378         0.216838          0.697107
# 2   207833831            6.378         0.216838          0.697107
# 3   207833831            6.378         0.216838          0.697107
# 4   207833831            6.378         0.216838          0.697107
#
#    population_65_above
# 0             0.086055
# 1             0.086055
# 2             0.086055
# 3             0.086055
# 4             0.086055

# %% [markdown]
# ### Calculate `cases_10k`, `diff_cases_10k`, `deaths_10k`, `diff_deaths_10k`

# %%
df3['cases_10k']       = df3['ConfirmedCases'] / df3['population'] * 10000
df3['diff_cases_10k']  = df3['diff_cases'] / df3['population'] * 10000
df3['deaths_10k']      = df3['Fatalities'] / df3['population'] * 10000
df3['diff_deaths_10k'] = df3['diff_deaths'] / df3['population'] * 10000
df3['cases_physician'] = df3['cases_10k'] / df3['physicians_per_10k']
df3['deaths_physician'] = df3['deaths_10k'] / df3['physicians_per_10k']

# %%
df3.head()
# Out:
#   Country_Region       Date  ConfirmedCases  Fatalities first_case  days  \
# 0         Brazil 2020-03-13           151.0         0.0 2020-03-13     0
# 1         Brazil 2020-03-14           151.0         0.0 2020-03-13     1
# 2         Brazil 2020-03-15           162.0         0.0 2020-03-13     2
# 3         Brazil 2020-03-16           200.0         0.0 2020-03-13     3
# 4         Brazil 2020-03-17           321.0         1.0 2020-03-13     4
#
#    diff_cases  diff_deaths country       hdi  ...  death_rate_1000  \
# 0         NaN          NaN  Brazil  0.761153  ...            6.378
# 1         0.0          0.0  Brazil  0.761153  ...            6.378
# 2        11.0          0.0  Brazil  0.761153  ...            6.378
# 3        38.0          0.0  Brazil  0.761153  ...            6.378
# 4       121.0          1.0  Brazil  0.761153  ...            6.378
#
#    population_0_14  population_15_64  population_65_above  cases_10k  \
# 0         0.216838          0.697107             0.086055   0.007265
# 1         0.216838          0.697107             0.086055   0.007265
# 2         0.216838          0.697107             0.086055   0.007795
# 3         0.216838          0.697107             0.086055   0.009623
# 4         0.216838          0.697107             0.086055   0.015445
#
#    diff_cases_10k  deaths_10k  diff_deaths_10k  cases_physician  \
# 0             NaN    0.000000              NaN         0.000338
# 1        0.000000    0.000000         0.000000         0.000338
# 2        0.000529    0.000000         0.000000         0.000363
# 3        0.001828    0.000000         0.000000         0.000448
# 4        0.005822    0.000048         0.000048         0.000718
#
#    deaths_physician
# 0          0.000000
# 1          0.000000
# 2          0.000000
# 3          0.000000
# 4          0.000002
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Export consolidated database

# %%
filename = 'output/consolidated_db.csv'
df3.to_csv(filename, index=False)

# %% [markdown]
# ## Exploratory Data

# %%
@interact(metric=df3.columns)
def explore(metric='diff_cases'):
    plt.figure(figsize=(12,8))
    for c in df3['country'].unique():
        mask = df3['country'] == c
        plt.plot(df3['Date'][mask], df3[metric][mask], label=c)
    plt.legend()
# Out:
# interactive(children=(Dropdown(description='metric', index=6, options=('Country_Region', 'Date', 'ConfirmedCas…

# %%
@interact(metric=df3.columns)
def explore_hbar(metric='diff_cases'):
    plt.figure(figsize=(12,8))
    mask = df3['Date'] == '2020-04-02'
    plt.bar(x=df3['country'].unique(), height=df3[metric][mask].apply(float))
    plt.xticks(rotation=90)
# Out:
# interactive(children=(Dropdown(description='metric', index=6, options=('Country_Region', 'Date', 'ConfirmedCas…

# %%
df_hdi
# Out:
#            country       hdi  skilled_employ_ratio  physicians_per_10k  \
# 3          Germany  0.938785              5.791743              42.087
# 14  United Kingdom  0.920352              5.748646              28.058
# 18           Japan  0.914696              3.540948              24.118
# 22    Korea, South  0.905832              2.935321              23.661
# 24           Spain  0.892788              2.588969              40.691
# 26          France  0.891057              4.652125              32.349
# 28           Italy  0.882584              3.293292              40.931
# 79          Brazil  0.761153              1.349538              21.499
#
#     hospital_beds_per_10k  vulnerable_employment_perc_emp
# 3                    83.0                             5.9
# 14                   28.0                            13.0
# 18                  134.0                             8.4
# 22                  115.0                            23.5
# 24                   30.0                            11.3
# 26                   65.0                             7.4
# 28                   34.0                            17.0
# 79                   22.0                            27.6
